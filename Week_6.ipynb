# %% [markdown]
# <a href="https://colab.research.google.com/github/MichaelTj02/ComputerVision_Group17/blob/main/Week_6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# <center><h1> <b>Image Dataset Analysis and Project Development with YOLO </b> </center> </h1>
#
# In this tutorial, we will see how image datasets with different types of tasks such as detection , segmentation etc. look like, and how they are labelled, specifically in YOLO format.
#
# Then, we will download one dataset to explore it and clean it if required.

# %% [markdown]
# The dataset should be labelled by arranging them in the following folders heirarchy.
#
#               root/
#               |-- class1/
#               |   |-- img1.jpg
#               |   |-- img2.jpg
#               |   |-- ...
#               |
#               |-- class2/
#               |   |-- img1.jpg
#               |   |-- img2.jpg
#               |   |-- ...
#               |
#               |-- class3/
#               |   |-- img1.jpg
#               |   |-- img2.jpg
#               |   |-- ...
#               |
#               |-- ...
#
# In this folder structure, the root directory contains one subdirectory for each class in the dataset. Each subdirectory is named after the corresponding class and contains all the images for that class.
#
# For example:
#
#               cifar-10-/
#               |
#               |-- train/
#               |   |-- airplane/
#               |   |   |-- 10008_airplane.png
#               |   |   |-- 10009_airplane.png
#               |   |   |-- ...
#               |   |
#               |   |-- automobile/
#               |   |   |-- 1000_automobile.png
#               |   |   |-- 1001_automobile.png
#               |   |   |-- ...
#               |   |
#               |   |-- bird/
#               |   |   |-- 10014_bird.png
#               |   |   |-- 10015_bird.png
#               |   |   |-- ...
#               |   |
#               |   |-- ...
#               |
#               |-- test/
#               |   |-- airplane/
#               |   |   |-- 10_airplane.png
#               |   |   |-- 11_airplane.png
#               |   |   |-- ...
#               |   |
#               |   |-- automobile/
#               |   |   |-- 100_automobile.png
#               |   |   |-- 101_automobile.png
#               |   |   |-- ...
#               |   |
#               |   |-- bird/
#               |   |   |-- 1000_bird.png
#               |   |   |-- 1001_bird.png
#               |   |   |-- ...
#               |   |
#               |   |-- ...

# %% [markdown]
# ## **Object Detection**

# %% [markdown]
# Object detection is a task that involves identifying the location and class of objects in an image or video stream.
#
# The output of an object detector is a set of bounding boxes that enclose the objects in the image, along with class labels and confidence scores for each box.

# %% [markdown]
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# <img align="left" src="https://user-images.githubusercontent.com/26833433/243418624-5785cb93-74c9-4541-9179-d5c6782d491a.png" width="600">

# %% [markdown]
# **Labelling format**
#
# In object detection tasks, various labeling formats are used to annotate images with information about the objects present. These formats typically include details about the object's class and location within the image. Here are some of the most common labeling formats:
#
# 1. COCO
# 2. YOLO
# 3. CSV
# 5. XML
# 6. PASCAL VOC
#
# We will be discussing only YOLO format, as you will be using YOLO framework for your project:
#
# - One .txt file with labels file per image
# - One row per object
# - Each row contains:
#
#       class_id bbox_x_center bbox_y_center bbox_width bbox_height
# - Box coordinates must be normalized between 0 and 1
#
#
# An example:

# %% [markdown]
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# <img align="left" src="https://user-images.githubusercontent.com/26833433/91506361-c7965000-e886-11ea-8291-c72b98c25eec.jpg" width="600">

# %% [markdown]
# Corresponding label text file should look like:
#
#
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# <img align="left" src="https://user-images.githubusercontent.com/26833433/112467037-d2568c00-8d66-11eb-8796-55402ac0d62f.png" width="600">

# %% [markdown]
# **Labelling format for YOLO**
#
#
# - One .txt file with labels file per image
# - One row per object
# - Each row contains:
#   - class index: An integer representing the class of the object (e.g., 0 for person, 1 for car, etc.).
#   - bounding coordinates: The bounding coordinates around the mask area, normalized to be between 0 and 1.
#
#
#       <class-index> <x1> <y1> <x2> <y2> ... <xn> <yn>
#
#
# Here is an example of the YOLO dataset format for a single image with two objects made up of a 3-point segment and a 5-point segment.
#
#
#       0 0.681 0.485 0.670 0.487 0.676 0.487
#       1 0.504 0.000 0.501 0.004 0.498 0.004 0.493 0.010 0.492 0.0104

# %% [markdown]
# ## FOLDERS HEIRARCHY

# %% [markdown]
#  We need to convert the dataset into a specific heirarchy of folders for all the tasks except for task of classification.
#
#
# The directories should be in the following format:
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **COCO128 Dataset**
#
# This section aims to introduce you to COCO dataset frequently used in Artificial Intelligence (AI).It is a foundational dataset in AI, widely used for tasks like object detection, segmentation, and image captioning.
#
#
# It Contains over 330,000 images with more than 200,000 labeled across 80 object categories. Unique for its richly annotated images, including object segmentation.It is widely used in computer vision research and has been used to train and evaluate many state-of-the-art object detection and segmentation models.
#
# Link to full dataset: https://cocodataset.org/#home

# %% [markdown]
# We are going using coco128 dataset.This dataset contains the first 128 images of COCO train 2017. It is used as the tutorial dataset for YOLO.
#
# Download the dataset from:
# https://www.kaggle.com/datasets/ultralytics/coco128/data

# %% [markdown]
# ## Dataset Visualization

# %% [markdown]
# To draw bounding boxes on images we need to understand the labelling format used by this dataset. The labels for this dataset are stored in YOLO format. i.e.
#
#         class_id bbox_x_center bbox_y_center bbox_width bbox_height

# %% [markdown]
# The class_id is the numerical number assigned to different class labels as shown below:

# %%
class_labels = {
    0: "with helmet",
    1: "without helmet",
    2: "rider",
    3: "number plate",
}

# %% [markdown]
# The rest of the four values i.e.
#
#     0.479492 0.688771 0.955609 0.5955
#
# indidicate the location of the bounding box.
#
# These values are normalized, which should be converted to a format that can be used as coordinate values of rectangle function (of cv2).

# %% [markdown]
# First import the required libraries:

# %%
import cv2
import matplotlib.pyplot as plt
import random as random
import os

# %% [markdown]
# Set all the paths of the dataset:

# %% [markdown]
# Data Cleaning For Train Dataset

# %%
# Michael dataset path
dataset_path = "/content/drive/MyDrive/SFU/300 Level Courses/IAT360/ComputerVisionProject/ComputerVisionDataset"

# %%
# Ryan's dataset path
dataset_path = "/content/drive/MyDrive/ComputerVisionProject/ComputerVisionDataset"

# %%
# Get the list of all images paths in the dataset
image_paths = [os.path.join(dataset_path, "images/train", image_name) for image_name in os.listdir(os.path.join(dataset_path, "images/train"))]

# Get the list of all labels paths in the dataset
label_paths = [os.path.join(dataset_path, "labels/train", label_name) for label_name in os.listdir(os.path.join(dataset_path, "labels/train"))]

print (image_paths)
# Out:
# ['/content/drive/MyDrive/ComputerVisionProject/ComputerVisionDataset/images/train/new13.jpg', '/content/drive/MyDrive/ComputerVisionProject/ComputerVisionDataset/images/train/new139.jpg', '/content/drive/MyDrive/ComputerVisionProject/ComputerVisionDataset/images/train/new103.jpg', '/content/drive/MyDrive/ComputerVisionProject/ComputerVisionDataset/images/train/new112.jpg', '/content/drive/MyDrive/ComputerVisionProject/ComputerVisionDataset/images/train/new136.jpg', '/content/drive/MyDrive/ComputerVisionProject/ComputerVisionDataset/images/train/new128.jpg', '/content/drive/MyDrive/ComputerVisionProject/ComputerVisionDataset/images/train/new124.jpg', '/content/drive/MyDrive/ComputerVisionProject/ComputerVisionDataset/images/train/new120.jpg', '/content/drive/MyDrive/ComputerVisionProject/ComputerVisionDataset/images/train/new10.jpg', '/content/drive/MyDrive/ComputerVisionProject/ComputerVisionDataset/images/train/new126.jpg', '/content/drive/MyDrive/ComputerVisionProject/ComputerVisionDataset/images/train/new121.jpg', '/content/drive/MyDrive/ComputerVisionProject/ComputerVisionDataset/images/train/new138.jpg', '/content/drive/MyDrive/ComputerVisionProject/ComputerVisionDataset/images/train/new130.jpg', '/content/drive/MyDrive/ComputerVisionProject/ComputerVisionDataset/images/train/new101.jpg', '/content/drive/MyDrive/ComputerVisionProject/ComputerVisionDataset/images/train/new141.jpg', '/content/drive/MyDrive/ComputerVisionProject/ComputerVisionDataset/images/train/new108.jpg', '/content/drive/MyDrive/ComputerVisionProject/ComputerVisionDataset/images/train/new11.jpg', '/content/drive/MyDrive/ComputerVisionProject/ComputerVisionDataset/images/train/new142.png', '/content/drive/MyDrive/ComputerVisionProject/ComputerVisionDataset/images/train/new129.jpg', '/content/drive/MyDrive/ComputerVisionProject/ComputerVisionDataset/images/train/new134.jpg', '/content/drive/MyDrive/ComputerVisionProject/ComputerVisionDataset/images/train/new1.jpg', '/content/drive/MyDrive/ComputerVisionProject/ComputerVisionDataset/images/train/new133.jpg', '/content/drive/MyDrive/ComputerVisionProject/ComputerVisionDataset/images/train/new132.jpg', '/content/drive/MyDrive/ComputerVisionProject/ComputerVisionDataset/images/train/new135.jpg', '/content/drive/MyDrive/ComputerVisionProject/ComputerVisionDataset/images/train/new116.jpg', '/content/drive/MyDrive/ComputerVisionProject/ComputerVisionDataset/images/train/new144.png', '/content/drive/MyDrive/ComputerVisionProject/ComputerVisionDataset/images/train/new119.jpg', '/content/drive/MyDrive/ComputerVisionProject/ComputerVisionDataset/images/train/new106.jpg', '/content/drive/MyDrive/ComputerVisionProject/ComputerVisionDataset/images/train/new122.jpg', '/content/drive/MyDrive/ComputerVisionProject/ComputerVisionDataset/images/train/new109.jpg', '/content/drive/MyDrive/ComputerVisionProject/ComputerVisionDataset/images/train/new117.jpg', '/content/drive/MyDrive/ComputerVisionProject/ComputerVisionDataset/images/train/new123.jpg', '/content/drive/MyDrive/ComputerVisionProject/ComputerVisionDataset/images/train/new125.jpg', '/content/drive/MyDrive/ComputerVisionProject/ComputerVisionDataset/images/train/new118.jpg', '/content/drive/MyDrive/ComputerVisionProject/ComputerVisionDataset/images/train/new15.jpg', '/content/drive/MyDrive/ComputerVisionProject/ComputerVisionDataset/images/train/new102.jpg', '/content/drive/MyDrive/ComputerVisionProject/ComputerVisionDataset/images/train/new140.jpg', '/content/drive/MyDrive/ComputerVisionProject/ComputerVisionDataset/images/train/new114.jpg', '/content/drive/MyDrive/ComputerVisionProject/ComputerVisionDataset/images/train/new100.jpg', '/content/drive/MyDrive/ComputerVisionProject/ComputerVisionDataset/images/train/new143.png', '/content/drive/MyDrive/ComputerVisionProject/ComputerVisionDataset/images/train/new110.jpg', '/content/drive/MyDrive/ComputerVisionProject/ComputerVisionDataset/images/train/new2.jpg', '/content/drive/MyDrive/ComputerVisionProject/ComputerVisio ...

# %% [markdown]
# The funtion "draw_yolo_box", takes input an image path and its corresponding label path. Then, draws the bounding boxes and write the object's label in each box. Finally it displays the images

# %%
def draw_yolo_bbox(image_path, label_path):
    # Load image
    image = cv2.imread(image_path)
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    height, width, _ = image.shape

    # Read label file
    with open(label_path, 'r') as file:
        bboxes = file.readlines()

    # Draw each bbox
    for bbox in bboxes:
        class_id, x_center, y_center, bbox_width, bbox_height = [float(x) for x in bbox.split()]

        # Convert YOLO bbox format to rectangle coordinates
        x1 = int((x_center - bbox_width / 2) * width)
        y1 = int((y_center - bbox_height / 2) * height)
        x2 = int((x_center + bbox_width / 2) * width)
        y2 = int((y_center + bbox_height / 2) * height)

        # Draw rectangle
        cv2.rectangle(image, (x1, y1), (x2, y2), (255, 0, 0), 2)
        # Put label (class_id) near the bbox
        label = class_labels[int(class_id)]
        cv2.putText(image, label, (x1, y1+20), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255,0,0), 2)
    # Display image
    plt.imshow(image)
    plt.axis('off')
    plt.show()

# %% [markdown]
# The function "print_random_images" takes in input the list of images' paths, a number defining how much images we want to print. So it randomly selects the images to display and calls "draw_yolo_bbox".

# %%
def print_random_images(photos: list, n: int = 5):
  for im in range(n):
        random_photo_path = random.choice(photos)
        name=random_photo_path.split('/')[-1].split('.')[0]
        label_path=dataset_path+"/labels/train/"+name+".txt"
        draw_yolo_bbox(random_photo_path ,label_path )

# %% [markdown]
# Now, finally calling the function to display 6 images randomly.

# %%
print_random_images(image_paths,n=6 )

# %% [markdown]
# ## Dataset Cleaning

# %% [markdown]
# Interestingly, we found out that this dataset is not clean. i.e. labels of some of the images are missing and there are extra labels. So, we need to find out the missing labels files and remove that from the labels folder. Also, we need to find out missing images, which we also need to remove from the images folder.

# %%
#we already have a list of images' paths and labels' path, stored in variables : image_paths and label_paths
print(image_paths)
print(label_paths)
# Out:
# ['/content/drive/MyDrive/ComputerVisionProject/ComputerVisionDataset/images/train/new13.jpg', '/content/drive/MyDrive/ComputerVisionProject/ComputerVisionDataset/images/train/new139.jpg', '/content/drive/MyDrive/ComputerVisionProject/ComputerVisionDataset/images/train/new103.jpg', '/content/drive/MyDrive/ComputerVisionProject/ComputerVisionDataset/images/train/new112.jpg', '/content/drive/MyDrive/ComputerVisionProject/ComputerVisionDataset/images/train/new136.jpg', '/content/drive/MyDrive/ComputerVisionProject/ComputerVisionDataset/images/train/new128.jpg', '/content/drive/MyDrive/ComputerVisionProject/ComputerVisionDataset/images/train/new124.jpg', '/content/drive/MyDrive/ComputerVisionProject/ComputerVisionDataset/images/train/new120.jpg', '/content/drive/MyDrive/ComputerVisionProject/ComputerVisionDataset/images/train/new10.jpg', '/content/drive/MyDrive/ComputerVisionProject/ComputerVisionDataset/images/train/new126.jpg', '/content/drive/MyDrive/ComputerVisionProject/ComputerVisionDataset/images/train/new121.jpg', '/content/drive/MyDrive/ComputerVisionProject/ComputerVisionDataset/images/train/new138.jpg', '/content/drive/MyDrive/ComputerVisionProject/ComputerVisionDataset/images/train/new130.jpg', '/content/drive/MyDrive/ComputerVisionProject/ComputerVisionDataset/images/train/new101.jpg', '/content/drive/MyDrive/ComputerVisionProject/ComputerVisionDataset/images/train/new141.jpg', '/content/drive/MyDrive/ComputerVisionProject/ComputerVisionDataset/images/train/new108.jpg', '/content/drive/MyDrive/ComputerVisionProject/ComputerVisionDataset/images/train/new11.jpg', '/content/drive/MyDrive/ComputerVisionProject/ComputerVisionDataset/images/train/new142.png', '/content/drive/MyDrive/ComputerVisionProject/ComputerVisionDataset/images/train/new129.jpg', '/content/drive/MyDrive/ComputerVisionProject/ComputerVisionDataset/images/train/new134.jpg', '/content/drive/MyDrive/ComputerVisionProject/ComputerVisionDataset/images/train/new1.jpg', '/content/drive/MyDrive/ComputerVisionProject/ComputerVisionDataset/images/train/new133.jpg', '/content/drive/MyDrive/ComputerVisionProject/ComputerVisionDataset/images/train/new132.jpg', '/content/drive/MyDrive/ComputerVisionProject/ComputerVisionDataset/images/train/new135.jpg', '/content/drive/MyDrive/ComputerVisionProject/ComputerVisionDataset/images/train/new116.jpg', '/content/drive/MyDrive/ComputerVisionProject/ComputerVisionDataset/images/train/new144.png', '/content/drive/MyDrive/ComputerVisionProject/ComputerVisionDataset/images/train/new119.jpg', '/content/drive/MyDrive/ComputerVisionProject/ComputerVisionDataset/images/train/new106.jpg', '/content/drive/MyDrive/ComputerVisionProject/ComputerVisionDataset/images/train/new122.jpg', '/content/drive/MyDrive/ComputerVisionProject/ComputerVisionDataset/images/train/new109.jpg', '/content/drive/MyDrive/ComputerVisionProject/ComputerVisionDataset/images/train/new117.jpg', '/content/drive/MyDrive/ComputerVisionProject/ComputerVisionDataset/images/train/new123.jpg', '/content/drive/MyDrive/ComputerVisionProject/ComputerVisionDataset/images/train/new125.jpg', '/content/drive/MyDrive/ComputerVisionProject/ComputerVisionDataset/images/train/new118.jpg', '/content/drive/MyDrive/ComputerVisionProject/ComputerVisionDataset/images/train/new15.jpg', '/content/drive/MyDrive/ComputerVisionProject/ComputerVisionDataset/images/train/new102.jpg', '/content/drive/MyDrive/ComputerVisionProject/ComputerVisionDataset/images/train/new140.jpg', '/content/drive/MyDrive/ComputerVisionProject/ComputerVisionDataset/images/train/new114.jpg', '/content/drive/MyDrive/ComputerVisionProject/ComputerVisionDataset/images/train/new100.jpg', '/content/drive/MyDrive/ComputerVisionProject/ComputerVisionDataset/images/train/new143.png', '/content/drive/MyDrive/ComputerVisionProject/ComputerVisionDataset/images/train/new110.jpg', '/content/drive/MyDrive/ComputerVisionProject/ComputerVisionDataset/images/train/new2.jpg', '/content/drive/MyDrive/ComputerVisionProject/ComputerVisio ...
# ['/content/drive/MyDrive/ComputerVisionProject/ComputerVisionDataset/labels/train/new150.txt', '/content/drive/MyDrive/ComputerVisionProject/ComputerVisionDataset/labels/train/new43.txt', '/content/drive/MyDrive/ComputerVisionProject/ComputerVisionDataset/labels/train/new158.txt', '/content/drive/MyDrive/ComputerVisionProject/ComputerVisionDataset/labels/train/new77.txt', '/content/drive/MyDrive/ComputerVisionProject/ComputerVisionDataset/labels/train/new92.txt', '/content/drive/MyDrive/ComputerVisionProject/ComputerVisionDataset/labels/train/new79.txt', '/content/drive/MyDrive/ComputerVisionProject/ComputerVisionDataset/labels/train/new5.txt', '/content/drive/MyDrive/ComputerVisionProject/ComputerVisionDataset/labels/train/new156.txt', '/content/drive/MyDrive/ComputerVisionProject/ComputerVisionDataset/labels/train/new75.txt', '/content/drive/MyDrive/ComputerVisionProject/ComputerVisionDataset/labels/train/new118.txt', '/content/drive/MyDrive/ComputerVisionProject/ComputerVisionDataset/labels/train/new6.txt', '/content/drive/MyDrive/ComputerVisionProject/ComputerVisionDataset/labels/train/new110.txt', '/content/drive/MyDrive/ComputerVisionProject/ComputerVisionDataset/labels/train/new51.txt', '/content/drive/MyDrive/ComputerVisionProject/ComputerVisionDataset/labels/train/new97.txt', '/content/drive/MyDrive/ComputerVisionProject/ComputerVisionDataset/labels/train/new163.txt', '/content/drive/MyDrive/ComputerVisionProject/ComputerVisionDataset/labels/train/new170.txt', '/content/drive/MyDrive/ComputerVisionProject/ComputerVisionDataset/labels/train/new36.txt', '/content/drive/MyDrive/ComputerVisionProject/ComputerVisionDataset/labels/train/new153.txt', '/content/drive/MyDrive/ComputerVisionProject/ComputerVisionDataset/labels/train/new168.txt', '/content/drive/MyDrive/ComputerVisionProject/ComputerVisionDataset/labels/train/new52.txt', '/content/drive/MyDrive/ComputerVisionProject/ComputerVisionDataset/labels/train/new55.txt', '/content/drive/MyDrive/ComputerVisionProject/ComputerVisionDataset/labels/train/new2.txt', '/content/drive/MyDrive/ComputerVisionProject/ComputerVisionDataset/labels/train/new169.txt', '/content/drive/MyDrive/ComputerVisionProject/ComputerVisionDataset/labels/train/new20.txt', '/content/drive/MyDrive/ComputerVisionProject/ComputerVisionDataset/labels/train/new108.txt', '/content/drive/MyDrive/ComputerVisionProject/ComputerVisionDataset/labels/train/new187.txt', '/content/drive/MyDrive/ComputerVisionProject/ComputerVisionDataset/labels/train/new165.txt', '/content/drive/MyDrive/ComputerVisionProject/ComputerVisionDataset/labels/train/new182.txt', '/content/drive/MyDrive/ComputerVisionProject/ComputerVisionDataset/labels/train/new183.txt', '/content/drive/MyDrive/ComputerVisionProject/ComputerVisionDataset/labels/train/new180.txt', '/content/drive/MyDrive/ComputerVisionProject/ComputerVisionDataset/labels/train/new90.txt', '/content/drive/MyDrive/ComputerVisionProject/ComputerVisionDataset/labels/train/new40.txt', '/content/drive/MyDrive/ComputerVisionProject/ComputerVisionDataset/labels/train/new50.txt', '/content/drive/MyDrive/ComputerVisionProject/ComputerVisionDataset/labels/train/new30.txt', '/content/drive/MyDrive/ComputerVisionProject/ComputerVisionDataset/labels/train/new146.txt', '/content/drive/MyDrive/ComputerVisionProject/ComputerVisionDataset/labels/train/new136.txt', '/content/drive/MyDrive/ComputerVisionProject/ComputerVisionDataset/labels/train/new15.txt', '/content/drive/MyDrive/ComputerVisionProject/ComputerVisionDataset/labels/train/new184.txt', '/content/drive/MyDrive/ComputerVisionProject/ComputerVisionDataset/labels/train/new147.txt', '/content/drive/MyDrive/ComputerVisionProject/ComputerVisionDataset/labels/train/new145.txt', '/content/drive/MyDrive/ComputerVisionProject/ComputerVisionDataset/labels/train/new42.txt', '/content/drive/MyDrive/ComputerVisionProject/ComputerVisionDataset/labels/train/new135.txt', '/content/drive/MyDrive/ComputerVisionProject/ComputerVisionDataset/labels ...

# %% [markdown]
# Now, we make a list of only the names of images' files and labels' files.
#
# e.g.  only  000000000531 without the extension

# %%
# Get the list of filenames without extensions
image_files = {file.split("/")[-1].split(".")[0] for file in image_paths}
label_files = {file.split("/")[-1].split(".")[0] for file in label_paths}

print(image_files)
# Out:
# {'new148', 'new134', 'new118', 'new101', 'new39', 'new150', 'new110', 'new96', 'new160', 'new162', 'new53', 'new61', 'new144', 'new143', 'new117', 'new21', 'new149', 'new63', 'new165', 'new129', 'new136', 'new18', 'new40', 'new146', 'new48', 'new173', 'new142', 'new75', 'new164', 'new153', 'new42', 'new44', 'new158', 'new176', 'new79', 'new77', 'new55', 'new27', 'new46', 'new13', 'new180', 'new70', 'new112', 'new122', 'new103', 'new97', 'new184', 'new120', 'new51', 'new2', 'new69', 'new84', 'new152', 'new141', 'new124', 'new64', 'new157', 'new29', 'new 174', 'new10', 'new92', 'new126', 'new132', 'new58', 'new71', 'new76', 'new16', 'new102', 'new106', 'new170', 'new108', 'new175', 'new138', 'new187', 'new151', 'new60', 'new85', 'new156', 'new168', 'new5', 'new121', 'new166', 'new181', 'new50', 'new119', 'new57', 'new133', 'new82', 'new72', 'new25', 'new125', 'new128', 'new114', 'new78', 'new109', 'new147', 'new91', 'new155', 'new15', 'new178', 'new22', 'new52', 'new3', 'new167', 'new68', 'new140', 'new171', 'new154', 'new90', 'new45', 'new130', 'new6', 'new8', 'new161', 'new81', 'new177', 'new182', 'new87', 'new116', 'new163', 'new37', 'new54', 'new139', 'new31', 'new7', 'new123', 'new135', 'new20', 'new159', 'new83', 'new11', 'new93', 'new1', 'new 172', 'new179', 'new95', 'new35', 'new145', 'new30', 'new100', 'new43', 'new183', 'new36', 'new169', 'new66'}

# %%
# Find extra files in each folder
extra_images = image_files - label_files
extra_labels = label_files - image_files

# Output the results
print(f"Extra images (without corresponding labels): {extra_images}")
print(f"Extra labels (without corresponding images): {extra_labels}")
# Out:
# Extra images (without corresponding labels): set()
# Extra labels (without corresponding images): set()

# %% [markdown]
# No need to run if no extra images and labels found

# %%
for file in extra_images:
     os.remove(os.path.join(dataset_path,"images/train/", file + '.jpg')) # or '.png' depending on your image format

for file in extra_labels:
     os.remove(os.path.join(dataset_path,"labels/train/", file + '.txt'))

# %% [markdown]
# Now removing them from the dataset:

# %%
os.path.join(dataset_path,"images/train/", file + '.jpg')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-a229f21fcbf6> in <cell line: 1>()
# ----> 1 os.path.join(dataset_path,"images/train/", file + '.jpg')
#
# NameError: name 'file' is not defined

# %% [markdown]
# Check again if it worked:

# %%
# Get the list of all images paths in the dataset
image_paths = [os.path.join(dataset_path, "images", image_name) for image_name in os.listdir(os.path.join(dataset_path, "images"))]

# Get the list of all labels paths in the dataset
label_paths = [os.path.join(dataset_path, "labels", label_name) for label_name in os.listdir(os.path.join(dataset_path, "labels"))]

# Get the list of filenames without extensions
image_files = {file.split("/")[-1].split(".")[0] for file in image_paths}
label_files = {file.split("/")[-1].split(".")[0] for file in label_paths}
# Find extra files in each folder
extra_images = image_files - label_files
extra_labels = label_files - image_files

# Output the results
print(f"Extra images (without corresponding labels): {extra_images}")
print(f"Extra labels (without corresponding images): {extra_labels}")
# Out:
# Extra images (without corresponding labels): set()
# Extra labels (without corresponding images): set()

# %% [markdown]
# There are none! great!
